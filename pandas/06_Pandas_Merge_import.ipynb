# %% [markdown]
# #  Pandas_Merge_by_Import files

# %%
import pandas as pd
import numpy as np

# %%
pop = pd.read_csv('state-population.csv')
areas = pd.read_csv('state-areas.csv')
abbrevs = pd.read_csv('state-abbrevs.csv')

# %%
pop.tail(10)
# Out:
#      state/region     ages  year   population
# 2534          USA  under18  2013   73585872.0
# 2535          USA    total  2013  316128839.0
# 2536          USA    total  2009  306771529.0
# 2537          USA  under18  2009   74134167.0
# 2538          USA  under18  2010   74119556.0
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0

# %%
areas.tail()
# Out:
#                    state  area (sq. mi)
# 47         West Virginia          24231
# 48             Wisconsin          65503
# 49               Wyoming          97818
# 50  District of Columbia             68
# 51           Puerto Rico           3515

# %%
abbrevs.tail()
# Out:
#             state abbreviation
# 46       Virginia           VA
# 47     Washington           WA
# 48  West Virginia           WV
# 49      Wisconsin           WI
# 50        Wyoming           WY

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
merged = pd.merge(pop, abbrevs, how='outer',
                  left_on='state/region', right_on='abbreviation')

merged.head()
# Out:
#   state/region     ages  year  population    state abbreviation
# 0           AL  under18  2012   1117489.0  Alabama           AL
# 1           AL    total  2012   4817528.0  Alabama           AL
# 2           AL  under18  2010   1130966.0  Alabama           AL
# 3           AL    total  2010   4785570.0  Alabama           AL
# 4           AL  under18  2011   1125763.0  Alabama           AL

# %%
merged = merged.drop('abbreviation', 1) # drop duplicate info
merged.head()
# Out:
#   state/region     ages  year  population    state
# 0           AL  under18  2012   1117489.0  Alabama
# 1           AL    total  2012   4817528.0  Alabama
# 2           AL  under18  2010   1130966.0  Alabama
# 3           AL    total  2010   4785570.0  Alabama
# 4           AL  under18  2011   1125763.0  Alabama

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
data = pd.merge(areas , merged, how = "outer", left_on = "state", right_on = "state")
data.head()
# Out:
#      state  area (sq. mi) state/region     ages    year  population
# 0  Alabama        52423.0           AL  under18  2012.0   1117489.0
# 1  Alabama        52423.0           AL    total  2012.0   4817528.0
# 2  Alabama        52423.0           AL  under18  2010.0   1130966.0
# 3  Alabama        52423.0           AL    total  2010.0   4785570.0
# 4  Alabama        52423.0           AL  under18  2011.0   1125763.0

# %%
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# dtype: bool

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2544 entries, 0 to 2543
# Data columns (total 5 columns):
# state/region    2544 non-null object
# ages            2544 non-null object
# year            2544 non-null int64
# population      2524 non-null float64
# state           2448 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 119.2+ KB

# %%
merged.describe()
# Out:
#               year    population
# count  2544.000000  2.524000e+03
# mean   2001.500000  6.805558e+06
# std       6.923547  2.855014e+07
# min    1990.000000  1.013090e+05
# 25%    1995.750000  7.423805e+05
# 50%    2001.500000  1.597005e+06
# 75%    2007.250000  4.547104e+06
# max    2013.000000  3.161288e+08
